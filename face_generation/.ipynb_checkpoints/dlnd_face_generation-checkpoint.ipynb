# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    
    input_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='input_real')
    input_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")

    return input_real, input_z, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def c2d_layer(inputs, filters, kernel_size, strides, padding, training, alpha, applyleakyrelu=True):
    
    layer = tf.layers.conv2d(inputs=inputs, filters=filters, kernel_size=kernel_size, strides=strides, padding=padding)
    layer = tf.layers.batch_normalization(layer, training=training)
    if(applyleakyrelu):
        layer = tf.maximum(alpha * layer, layer)
    
    return layer

# %%
def discriminator(images, reuse=False, n_units=128, alpha=0.01, training=True):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    
    with tf.variable_scope('discriminator', reuse=reuse):

        
        # Input layer is 28 x 28 x 3
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        relu1 = tf.maximum(alpha * x1, x1)
        # 14 x 14 x 64
        
        x2 = c2d_layer(relu1, 128, 5, 2, 'same', training, alpha)
        # 7 x 7 x 128
        
        x3 = c2d_layer(x2, 256, 5, 2, 'same', training, alpha)
        # 4 x 4 x 256

        # Flatten it
        flat = tf.reshape(x3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
    return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def c2dt_layer(inputs, filters, kernel_size, strides, padding, training, alpha, applyleakyrelu=True):
    
    layer = tf.layers.conv2d_transpose(inputs=inputs, filters=filters, kernel_size=kernel_size, strides=strides, padding=padding)
    layer = tf.layers.batch_normalization(layer, training=training)
    if(applyleakyrelu):
        layer = tf.maximum(alpha * layer, layer)
    
    return layer

# %%
def generator(z, out_channel_dim, is_train=True, alpha=0.01):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    
    reuse = not is_train
    
    with tf.variable_scope('generator', reuse=reuse):
        
        # first fully conencted layer
        x0 = tf.layers.dense(z, 2 * 2 * 1024)
        
        # reshape
        x0 = tf.reshape(x0, (-1, 2, 2, 1024))
        x0 = tf.layers.batch_normalization(x0, training=is_train)
        x0 = tf.maximum(alpha * x0, x0)
        # now 2 x 2 x 1024
        
        #def c2dt_layer(inputs, filters, kernel_size, strides, padding, training, applyleakyrelu=True):
        x1 = c2dt_layer(x0, 512, 4, 2, 'same', is_train, alpha, True)
        # now 4 x 4 x 512
        
        x2 = c2dt_layer(x1, 256, 4, 1, 'valid', is_train, alpha, True)
        # now 7 x 7 x 256
        
        
        x3 = c2dt_layer(x2, 256, 1, 1, 'same', is_train, alpha, True)
        # now 7 x 7 x 256
        
        x4 = c2dt_layer(x3, 128, 4, 2, 'same', is_train, alpha, True)
        # now 14 x 14 x 256
        
        x5 = c2dt_layer(x4, 128, 1, 1, 'same', is_train, alpha, True)
        # now 14 x 14 x 256

        # Output layer
        logits = tf.layers.conv2d_transpose(x5, out_channel_dim, 5, strides=2, padding='same')

        # now 28 x 28 x 3
        out = tf.tanh(logits)

        
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    
    
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    # It seems smooth method does not make much different to final result.
    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
   
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss
    



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt    
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode, num_images_show = 10, print_every = 10, show_every = 100):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    import time, datetime

    sample_z = np.random.uniform(-1, 1, size=z_dim)
    
    samples, losses = [], []
    steps = 0
    
    input_real, input_z, lr = model_inputs(data_shape[1], data_shape[2], data_shape[3], z_dim)
    d_loss, g_loss = model_loss(input_real, input_z, data_shape[3])
    d_opt, g_opt = model_opt(d_loss, g_loss, lr, beta1)
    
    
    with tf.Session() as sess:
        start = time.time()
        print("Start: {}".format(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(start))))
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1

                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(d_opt, feed_dict={input_real: batch_images, input_z: batch_z, lr: learning_rate})
                _ = sess.run(g_opt, feed_dict={input_real: batch_images, input_z: batch_z, lr: learning_rate})

                if steps % print_every == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    # Save losses to view after training
                    losses.append((train_loss_d, train_loss_g))

                if steps % show_every == 0:
                    #def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
                   show_generator_output(sess, num_images_show, input_z, data_shape[3], data_image_mode)
        show_generator_output(sess, num_images_show, input_z, data_shape[3], data_image_mode) 
        done = time.time()
        elapsed = done - start
        print("Done at {} - elapsed time: {}".format(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(done)), str(datetime.timedelta(seconds=elapsed))))

        
    return losses, samples

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 50 #64
z_dim = 150 #150
learning_rate = 0.001 #0.002
beta1 = 0.05 # 0.05


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Start: 2018-03-10 17:33:49
# Epoch 1/2... Discriminator Loss: 0.3600... Generator Loss: 6.9932
# Epoch 1/2... Discriminator Loss: 2.2713... Generator Loss: 9.3092
# Epoch 1/2... Discriminator Loss: 3.5185... Generator Loss: 0.0329
# Epoch 1/2... Discriminator Loss: 0.8813... Generator Loss: 0.6076
# Epoch 1/2... Discriminator Loss: 1.2296... Generator Loss: 1.8158
# Epoch 1/2... Discriminator Loss: 1.2210... Generator Loss: 3.8729
# Epoch 1/2... Discriminator Loss: 1.3859... Generator Loss: 4.1458
# Epoch 1/2... Discriminator Loss: 0.9665... Generator Loss: 3.0261
# Epoch 1/2... Discriminator Loss: 1.5528... Generator Loss: 3.4449
# Epoch 1/2... Discriminator Loss: 1.7799... Generator Loss: 4.7181
# Epoch 1/2... Discriminator Loss: 0.4328... Generator Loss: 1.8814
# Epoch 1/2... Discriminator Loss: 0.4527... Generator Loss: 2.6080
# Epoch 1/2... Discriminator Loss: 1.2417... Generator Loss: 4.5210
# Epoch 1/2... Discriminator Loss: 0.4509... Generator Loss: 3.6880
# Epoch 1/2... Discriminator Loss: 1.4752... Generator Loss: 0.2939
# Epoch 1/2... Discriminator Loss: 2.5656... Generator Loss: 0.0877
# Epoch 1/2... Discriminator Loss: 1.2424... Generator Loss: 0.4118
# Epoch 1/2... Discriminator Loss: 1.4980... Generator Loss: 0.2876
# Epoch 1/2... Discriminator Loss: 0.7381... Generator Loss: 0.8822
# Epoch 1/2... Discriminator Loss: 1.3123... Generator Loss: 0.3729
# Epoch 1/2... Discriminator Loss: 1.0956... Generator Loss: 0.4683
# Epoch 1/2... Discriminator Loss: 1.5238... Generator Loss: 0.2575
# Epoch 1/2... Discriminator Loss: 0.4828... Generator Loss: 1.4955
# Epoch 1/2... Discriminator Loss: 0.2070... Generator Loss: 2.2420
# Epoch 1/2... Discriminator Loss: 7.1158... Generator Loss: 9.6272
# Epoch 1/2... Discriminator Loss: 0.2213... Generator Loss: 6.7068
# Epoch 1/2... Discriminator Loss: 0.0805... Generator Loss: 3.4549
# Epoch 1/2... Discriminator Loss: 0.2458... Generator Loss: 3.6443
# Epoch 1/2... Discriminator Loss: 0.8668... Generator Loss: 0.6561
# Epoch 1/2... Discriminator Loss: 0.3250... Generator Loss: 1.8802
# Epoch 1/2... Discriminator Loss: 0.7615... Generator Loss: 2.7446
# Epoch 1/2... Discriminator Loss: 0.1692... Generator Loss: 4.9982
# Epoch 1/2... Discriminator Loss: 0.3953... Generator Loss: 1.5762
# Epoch 1/2... Discriminator Loss: 0.2096... Generator Loss: 2.7451
# Epoch 1/2... Discriminator Loss: 0.2601... Generator Loss: 2.3160
# Epoch 1/2... Discriminator Loss: 0.2248... Generator Loss: 2.2918
# Epoch 1/2... Discriminator Loss: 0.1201... Generator Loss: 3.4955
# Epoch 1/2... Discriminator Loss: 4.6248... Generator Loss: 7.4084
# Epoch 1/2... Discriminator Loss: 0.9239... Generator Loss: 3.1320
# Epoch 1/2... Discriminator Loss: 0.4830... Generator Loss: 1.4420
# Epoch 1/2... Discriminator Loss: 0.4273... Generator Loss: 1.3063
# Epoch 1/2... Discriminator Loss: 0.4538... Generator Loss: 1.3431
# Epoch 1/2... Discriminator Loss: 0.0899... Generator Loss: 5.5580
# Epoch 1/2... Discriminator Loss: 0.1517... Generator Loss: 4.5377
# Epoch 1/2... Discriminator Loss: 0.2919... Generator Loss: 1.5788
# Epoch 1/2... Discriminator Loss: 0.0790... Generator Loss: 5.9855
# Epoch 1/2... Discriminator Loss: 0.0600... Generator Loss: 5.3567
# Epoch 1/2... Discriminator Loss: 0.1083... Generator Loss: 2.7741
# Epoch 1/2... Discriminator Loss: 0.0495... Generator Loss: 3.5993
# Epoch 1/2... Discriminator Loss: 0.6506... Generator Loss: 6.5297
# Epoch 1/2... Discriminator Loss: 0.0981... Generator Loss: 4.4167
# Epoch 1/2... Discriminator Loss: 0.3351... Generator Loss: 1.4981
# Epoch 1/2... Discriminator Loss: 4.5131... Generator Loss: 10.4535
# Epoch 1/2... Discriminator Loss: 2.2489... Generator Loss: 0.1751
# Epoch 1/2... Discriminator Loss: 0.2484... Generator Loss: 4.8197
# Epoch 1/2... Discriminator Loss: 0.2655... Generator Loss: 3.7835
# Epoch 1/2... Discriminator Loss: 0.4014... Generator Loss: 1.2652
# Epoch 1/2... Discriminator Loss: 0.2304... Generator Loss: 2.6105
# Epoch 1/2... Discriminator Loss: 0.4892... Generator Loss: 1.2167
# Epoch 1/2... Discriminator Loss: 0.2259... Generator Loss: 5.4742
# Epoch 1/2... Discriminator Loss: 0.3896... Generator Loss: 1.4884
# Epoch 1/2... Discriminator Loss: 0.6803... Generator Loss: 5.5088
# Epoch 1/2... Discriminator Loss: 0.2436... Generator Loss: 2.4142
# Epoch 1/2... Discriminator Loss: 2.0119... Generator Loss: 0.2275
# Epoch 1/2... Discriminator Loss: 0.7308... Generator Loss: 5.4990
# Epoch 1/2... Discriminator Loss: 0.3614... Generator Loss: 1.5185
# Epoch 1/2... Discriminator Loss: 0.3005... Generator Loss: 2.1751
# Epoch 1/2... Discriminator Loss: 2.7835... Generator Loss: 8.3769
# Epoch 1/2... Discriminator Loss: 0.1549... Generator Loss: 2.6746
# Epoch 1/2... Discriminator Loss: 0.4049... Generator Loss: 5.6194
# Epoch 1/2... Discriminator Loss: 0.4291... Generator Loss: 1.1819
# Epoch 1/2... Discriminator Loss: 0.2362... Generator Loss: 2.4643
# Epoch 1/2... Discriminator Loss: 0.2397... Generator Loss: 2.1146
# Epoch 1/2... Discriminator Loss: 0.2928... Generator Loss: 1.9215
# Epoch 1/2... Discriminator Loss: 1.4134... Generator Loss: 6.6496
# Epoch 1/2... Discriminator Loss: 0.7083... Generator Loss: 0.9078
# Epoch 1/2... Discriminator Loss: 0.2436... Generator Loss: 1.8484
# Epoch 1/2... Discriminator Loss: 0.2793... Generator Loss: 1.8891
# Epoch 1/2... Discriminator Loss: 0.0556... Generator Loss: 3.6647
# Epoch 1/2... Discriminator Loss: 0.4736... Generator Loss: 5.0764
# Epoch 1/2... Discriminator Loss: 1.9222... Generator Loss: 0.2199
# Epoch 1/2... Discriminator Loss: 0.9128... Generator Loss: 0.6701
# Epoch 1/2... Discriminator Loss: 0.4562... Generator Loss: 1.3728
# Epoch 1/2... Discriminator Loss: 0.6620... Generator Loss: 0.9447
# Epoch 1/2... Discriminator Loss: 0.1799... Generator Loss: 2.2084
# Epoch 1/2... Discriminator Loss: 0.1664... Generator Loss: 5.3188
# Epoch 1/2... Discriminator Loss: 0.6297... Generator Loss: 0.9561
# Epoch 1/2... Discriminator Loss: 0.9288... Generator Loss: 7.1730
# Epoch 1/2... Discriminator Loss: 0.3736... Generator Loss: 5.8197
# Epoch 1/2... Discriminator Loss: 0.6669... Generator Loss: 0.9317
# Epoch 1/2... Discriminator Loss: 0.1040... Generator Loss: 6.1058
# Epoch 1/2... Discriminator Loss: 2.8662... Generator Loss: 8.1040
# Epoch 1/2... Discriminator Loss: 0.0491... Generator Loss: 3.9446
# Epoch 1/2... Discriminator Loss: 0.1318... Generator Loss: 4.7776
# Epoch 1/2... Discriminator Loss: 0.3400... Generator Loss: 2.1390
# Epoch 1/2... Discriminator Loss: 0.1952... Generator Loss: 2.6158
# Epoch 1/2... Discriminator Loss: 0.0573... Generator Loss: 6.3510
# Epoch 1/2... Discriminator Loss: 0.3739... Generator Loss: 1.8218
# Epoch 1/2... Discriminator Loss: 0.7685... Generator Loss: 8.0264
# Epoch 1/2... Discriminator Loss: 0.2331... Generator Loss: 2.1134
# Epoch 1/2... Discriminator Loss: 0.1384... Generator Loss: 2.5407
# Epoch 1/2... Discriminator Loss: 1.0539... Generator Loss: 0.7339
# Epoch 1/2... Discriminator Loss: 0.0692... Generator Loss: 3.7570
# Epoch 1/2... Discriminator Loss: 2.3005... Generator Loss: 0.1499
# Epoch 1/2... Discriminator Loss: 0.3151... Generator Loss: 2.3198
# Epoch 1/2... Discriminator Loss: 1.6966... Generator Loss: 5.3844
# Epoch 1/2... Discriminator Loss: 0.7561... Generator Loss: 0.8576
# Epoch 1/2... Discriminator Loss: 0.8291... Generator Loss: 0.7587
# Epoch 1/2... Discriminator Loss: 1.2031... Generator Loss: 0.6326
# Epoch 1/2... Discriminator Loss: 0.2007... Generator Loss: 4.1778
# Epoch 1/2... Discriminator Loss: 0.1965... Generator Loss: 2.3206
# Epoch 1/2... Discriminator Loss: 0.0903... Generator Loss: 3.7711
# Epoch 1/2... Discriminator Loss: 0.2900... Generator Loss: 2.2787
# Epoch 1/2... Discriminator Loss: 0.0752... Generator Loss: 4.4819
# Epoch 1/2... Discriminator Loss: 0.9874... Generator Loss: 0.8172
# Epoch 1/2... Discriminator Loss: 0.4148... Generator Loss: 1.7524
# Epoch 1/2... Discriminator Loss: 0.2079... Generator Loss: 2.7051
# Epoch 1/2... Discriminator Loss: 3.3903... Generator Loss: 8.3893
# Epoch 1/2... Discriminator Loss: 1.3226... Generator Loss: 5.6243
# Epoch 1/2... Discriminator Loss: 2.6023... Generator Loss: 6.6697
# Epoch 2/2... Discriminator Loss: 0.4012... Generator Loss: 2.5482
# Epoch 2/2... Discriminator Loss: 0.2540... Generator Loss: 2.2680
# Epoch 2/2... Discriminator Loss: 1.0103... Generator Loss: 0.7316
# Epoch 2/2... Discriminator Loss: 0.3408... Generator Loss: 2.9100
# Epoch 2/2... Discriminator Loss: 0.2266... Generator Loss: 2.6046
# Epoch 2/2... Discriminator Loss: 1.6508... Generator Loss: 0.3920
# Epoch 2/2... Discriminator Loss: 1.3809... Generator Loss: 0.4205
# Epoch 2/2... Discriminator Loss: 0.4971... Generator Loss: 1.3682
# Epoch 2/2... Discriminator Loss: 0.1464... Generator Loss: 2.7980
# Epoch 2/2... Discriminator Loss: 1.9615... Generator Loss: 0.2449
# Epoch 2/2... Discriminator Loss: 0.1107... Generator Loss: 3.1751
# Epoch 2/2... Discriminator Loss: 0.0751... Generator Loss: 4.5461
# Epoch 2/2... Discriminator Loss: 0.1016... Generator Loss: 2.9151
# Epoch 2/2... Discriminator Loss: 0.4080... Generator Loss: 1.5851
# Epoch 2/2... Discriminator Loss: 0.4542... Generator Loss: 2.0850
# Epoch 2/2... Discriminator Loss: 0.4977... Generator Loss: 2.3888
# Epoch 2/2... Discriminator Loss: 0.5621... Generator Loss: 1.3126
# Epoch 2/2... Discriminator Loss: 2.2745... Generator Loss: 5.8136
# Epoch 2/2... Discriminator Loss: 1.2531... Generator Loss: 4.5418
# Epoch 2/2... Discriminator Loss: 0.8852... Generator Loss: 2.7667
# Epoch 2/2... Discriminator Loss: 0.4411... Generator Loss: 2.3326
# Epoch 2/2... Discriminator Loss: 0.9001... Generator Loss: 0.7504
# Epoch 2/2... Discriminator Loss: 0.6680... Generator Loss: 2.9737
# Epoch 2/2... Discriminator Loss: 1.7919... Generator Loss: 5.3911
# Epoch 2/2... Discriminator Loss: 0.2491... Generator Loss: 2.0429
# Epoch 2/2... Discriminator Loss: 1.6237... Generator Loss: 3.9245
# Epoch 2/2... Discriminator Loss: 0.5420... Generator Loss: 2.5049
# Epoch 2/2... Discriminator Loss: 0.8340... Generator Loss: 3.5635
# Epoch 2/2... Discriminator Loss: 0.6282... Generator Loss: 1.3831
# Epoch 2/2... Discriminator Loss: 0.3845... Generator Loss: 3.7836
# Epoch 2/2... Discriminator Loss: 0.5533... Generator Loss: 1.2293
# Epoch 2/2... Discriminator Loss: 2.3024... Generator Loss: 4.5310
# Epoch 2/2... Discriminator Loss: 0.4527... Generator Loss: 1.8081
# Epoch 2/2... Discriminator Loss: 0.5398... Generator Loss: 2.8358
# Epoch 2/2... Discriminator Loss: 0.4309... Generator Loss: 1.6323
# Epoch 2/2... Discriminator Loss: 0.8336... Generator Loss: 3.4735
# Epoch 2/2... Discriminator Loss: 0.2238... Generator Loss: 2.8649
# Epoch 2/2... Discriminator Loss: 0.2385... Generator Loss: 3.3386
# Epoch 2/2... Discriminator Loss: 0.5537... Generator Loss: 1.3665
# Epoch 2/2... Discriminator Loss: 1.3797... Generator Loss: 2.6246
# Epoch 2/2... Discriminator Loss: 1.1872... Generator Loss: 3.7460
# Epoch 2/2... Discriminator Loss: 1.1854... Generator Loss: 0.5417
# Epoch 2/2... Discriminator Loss: 0.9127... Generator Loss: 0.6868
# Epoch 2/2... Discriminator Loss: 0.6976... Generator Loss: 1.0075
# Epoch 2/2... Discriminator Loss: 1.8235... Generator Loss: 0.2779
# Epoch 2/2... Discriminator Loss: 0.4053... Generator Loss: 3.0625
# Epoch 2/2... Discriminator Loss: 1.3420... Generator Loss: 0.5990
# Epoch 2/2... Discriminator Loss: 0.8367... Generator Loss: 0.8683
# Epoch 2/2... Discriminator Loss: 0.7693... Generator Loss: 0.8658
# Epoch 2/2... Discriminator Loss: 0.4951... Generator Loss: 1.3356
# Epoch 2/2... Discriminator Loss: 2.1451... Generator Loss: 0.1904
# Epoch 2/2... Discriminator Loss: 1.4931... Generator Loss: 0.3996
# Epoch 2/2... Discriminator Loss: 0.2846... Generator Loss: 2.6951
# Epoch 2/2... Discriminator Loss: 2.5462... Generator Loss: 0.1331
# Epoch 2/2... Discriminator Loss: 1.4930... Generator Loss: 0.3775
# Epoch 2/2... Discriminator Loss: 1.1126... Generator Loss: 3.0574
# Epoch 2/2... Discriminator Loss: 0.5101... Generator Loss: 1.3929
# Epoch 2/2... Discriminator Loss: 1.1863... Generator Loss: 0.6296
# Epoch 2/2... Discriminator Loss: 1.1327... Generator Loss: 0.6109
# Epoch 2/2... Discriminator Loss: 0.6154... Generator Loss: 1.0531
# Epoch 2/2... Discriminator Loss: 0.8974... Generator Loss: 3.2531
# Epoch 2/2... Discriminator Loss: 2.2780... Generator Loss: 0.1633
# Epoch 2/2... Discriminator Loss: 0.4927... Generator Loss: 3.1406
# Epoch 2/2... Discriminator Loss: 0.8355... Generator Loss: 0.7809
# Epoch 2/2... Discriminator Loss: 2.8953... Generator Loss: 0.1298
# Epoch 2/2... Discriminator Loss: 0.7397... Generator Loss: 2.1159
# Epoch 2/2... Discriminator Loss: 0.3323... Generator Loss: 1.9590
# Epoch 2/2... Discriminator Loss: 1.4929... Generator Loss: 0.8051
# Epoch 2/2... Discriminator Loss: 0.4854... Generator Loss: 2.7212
# Epoch 2/2... Discriminator Loss: 0.7791... Generator Loss: 1.4236
# Epoch 2/2... Discriminator Loss: 2.3200... Generator Loss: 4.5710
# Epoch 2/2... Discriminator Loss: 0.3780... Generator Loss: 2.7148
# Epoch 2/2... Discriminator Loss: 0.3550... Generator Loss: 1.8781
# Epoch 2/2... Discriminator Loss: 0.9213... Generator Loss: 0.7621
# Epoch 2/2... Discriminator Loss: 1.3743... Generator Loss: 0.5443
# Epoch 2/2... Discriminator Loss: 1.2862... Generator Loss: 3.0633
# Epoch 2/2... Discriminator Loss: 1.0028... Generator Loss: 0.7282
# Epoch 2/2... Discriminator Loss: 1.4710... Generator Loss: 0.3932
# Epoch 2/2... Discriminator Loss: 0.4716... Generator Loss: 1.4257
# Epoch 2/2... Discriminator Loss: 1.2010... Generator Loss: 2.6888
# Epoch 2/2... Discriminator Loss: 0.2293... Generator Loss: 2.8092
# Epoch 2/2... Discriminator Loss: 2.1207... Generator Loss: 3.5137
# Epoch 2/2... Discriminator Loss: 0.9083... Generator Loss: 3.5923
# Epoch 2/2... Discriminator Loss: 1.6075... Generator Loss: 0.3652
# Epoch 2/2... Discriminator Loss: 0.3874... Generator Loss: 1.5869
# Epoch 2/2... Discriminator Loss: 0.2135... Generator Loss: 2.7424
# Epoch 2/2... Discriminator Loss: 2.5065... Generator Loss: 5.1151
# Epoch 2/2... Discriminator Loss: 0.7673... Generator Loss: 1.2042
# Epoch 2/2... Discriminator Loss: 2.1081... Generator Loss: 0.2228
# Epoch 2/2... Discriminator Loss: 1.0777... Generator Loss: 0.5825
# Epoch 2/2... Discriminator Loss: 0.1323... Generator Loss: 3.6248
# Epoch 2/2... Discriminator Loss: 1.4283... Generator Loss: 0.4084
# Epoch 2/2... Discriminator Loss: 0.5647... Generator Loss: 5.2515
# Epoch 2/2... Discriminator Loss: 0.4693... Generator Loss: 1.4267
# Epoch 2/2... Discriminator Loss: 0.7935... Generator Loss: 1.4240
# Epoch 2/2... Discriminator Loss: 0.3297... Generator Loss: 2.1449
# Epoch 2/2... Discriminator Loss: 0.8251... Generator Loss: 1.2110
# Epoch 2/2... Discriminator Loss: 0.4322... Generator Loss: 2.0500
# Epoch 2/2... Discriminator Loss: 1.0672... Generator Loss: 0.4988
# Epoch 2/2... Discriminator Loss: 0.1866... Generator Loss: 2.4683
# Epoch 2/2... Discriminator Loss: 1.6292... Generator Loss: 0.2824
# Epoch 2/2... Discriminator Loss: 1.9439... Generator Loss: 0.2349
# Epoch 2/2... Discriminator Loss: 1.5061... Generator Loss: 0.4465
# Epoch 2/2... Discriminator Loss: 1.0741... Generator Loss: 0.6586
# Epoch 2/2... Discriminator Loss: 0.5913... Generator Loss: 1.1491
# Epoch 2/2... Discriminator Loss: 0.0354... Generator Loss: 6.9146
# Epoch 2/2... Discriminator Loss: 0.0273... Generator Loss: 7.0702
# Epoch 2/2... Discriminator Loss: 0.0158... Generator Loss: 6.3578
# Epoch 2/2... Discriminator Loss: 0.1433... Generator Loss: 2.8369
# Epoch 2/2... Discriminator Loss: 3.2394... Generator Loss: 0.0606
# Epoch 2/2... Discriminator Loss: 0.3921... Generator Loss: 3.3579
# Epoch 2/2... Discriminator Loss: 1.1477... Generator Loss: 3.3375
# Epoch 2/2... Discriminator Loss: 0.5449... Generator Loss: 1.2123
# Epoch 2/2... Discriminator Loss: 1.6823... Generator Loss: 0.3205
# Epoch 2/2... Discriminator Loss: 0.4331... Generator Loss: 1.3982
# Epoch 2/2... Discriminator Loss: 1.3579... Generator Loss: 0.4825
# Epoch 2/2... Discriminator Loss: 0.7367... Generator Loss: 1.0224
# Epoch 2/2... Discriminator Loss: 0.3880... Generator Loss: 1.6650
# Epoch 2/2... Discriminator Loss: 0.3858... Generator Loss: 1.4914
# Epoch 2/2... Discriminator Loss: 0.6239... Generator Loss: 1.1437
# Done at 2018-03-10 17:40:31 - elapsed time: 0:06:42.384601

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 50
z_dim = 60
learning_rate = .0006
beta1 = .05


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
